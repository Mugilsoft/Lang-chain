# %%
#!pip install langgraph
#!pip install "nbconvert[webpdf]"
# Out:
# Requirement already satisfied: nbconvert[webpdf] in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (7.17.1)
# Requirement already satisfied: beautifulsoup4 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (4.15.0)
# Requirement already satisfied: bleach!=5.0.0 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert[webpdf]) (6.4.0)
# Requirement already satisfied: defusedxml in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (5.9.1)
# Requirement already satisfied: jupyterlab-pygments in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (3.3.3)
# Requirement already satisfied: nbclient>=0.5.0 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (0.11.0)
# Requirement already satisfied: nbformat>=5.7 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (5.10.4)
# Requirement already satisfied: packaging in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (26.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (2.20.0)
# Requirement already satisfied: traitlets>=5.1 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbconvert[webpdf]) (5.15.1)
# Collecting playwright (from nbconvert[webpdf])
#   Downloading playwright-1.62.0-py3-none-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: webencodings in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert[webpdf]) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert[webpdf]) (1.5.1)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from jupyter-core>=4.7->nbconvert[webpdf]) (4.10.1)
# Requirement already satisfied: jupyter-client>=7.0.0 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbclient>=0.5.0->nbconvert[webpdf]) (8.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from jupyter-client>=7.0.0->nbclient>=0.5.0->nbconvert[webpdf]) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=25.0 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from jupyter-client>=7.0.0->nbclient>=0.5.0->nbconvert[webpdf]) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from jupyter-client>=7.0.0->nbclient>=0.5.0->nbconvert[webpdf]) (6.5.7)
# Requirement already satisfied: typing-extensions>=4.13.0 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from jupyter-client>=7.0.0->nbclient>=0.5.0->nbconvert[webpdf]) (4.16.0)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbformat>=5.7->nbconvert[webpdf]) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from nbformat>=5.7->nbconvert[webpdf]) (4.26.0)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert[webpdf]) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert[webpdf]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert[webpdf]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert[webpdf]) (2026.6.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.0.0->nbclient>=0.5.0->nbconvert[webpdf]) (1.17.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from beautifulsoup4->nbconvert[webpdf]) (2.9)
# Collecting pyee<14,>=13 (from playwright->nbconvert[webpdf])
#   Downloading pyee-13.0.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in C:\Users\Manikandan\anaconda3\envs\langchain\Lib\site-packages (from playwright->nbconvert[webpdf]) (3.5.3)
# Downloading playwright-1.62.0-py3-none-win_amd64.whl (38.2 MB)
#    ---------------------------------------- 0.0/38.2 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.2 MB 5.6 MB/s eta 0:00:07
#    -- ------------------------------------- 2.4/38.2 MB 9.0 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/38.2 MB 9.8 MB/s eta 0:00:04
#    ------ --------------------------------- 5.8/38.2 MB 9.0 MB/s eta 0:00:04
#    ------ --------------------------------- 6.6/38.2 MB 7.7 MB/s eta 0:00:05
#    ------- -------------------------------- 7.3/38.2 MB 6.9 MB/s eta 0:00:05
#    -------- ------------------------------- 8.1/38.2 MB 6.3 MB/s eta 0:00:05
#    --------- ------------------------------ 8.9/38.2 MB 6.0 MB/s eta 0:00:05
#    --------- ------------------------------ 9.4/38.2 MB 5.6 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.0/38.2 MB 5.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 10.7/38.2 MB 5.1 MB/s eta 0:00:06
#    ----------- ---------------------------- 11.3/38.2 MB 4.9 MB/s eta 0:00:06
#    ------------ --------------------------- 12.1/38.2 MB 4.7 MB/s eta 0:00:06
#    ------------- -------------------------- 12.8/38.2 MB 4.6 MB/s eta 0:00:06
#    -------------- ------------------------- 13.4/38.2 MB 4.5 MB/s eta 0:00:06
#    -------------- ------------------------- 14.2/38.2 MB 4.4 MB/s eta 0:00:06
#    --------------- ------------------------ 14.9/38.2 MB 4.4 MB/s eta 0:00:06
#    ---------------- ----------------------- 15.5/38.2 MB 4.3 MB/s eta 0:00:06
#    ----------------- ---------------------- 16.3/38.2 MB 4.3 MB/s eta 0:00:06
#    ------------------ --------------------- 17.3/38.2 MB 4.3 MB/s eta 0:00:05
#    ------------------ --------------------- 17.8/38.2 MB 4.2 MB/s eta 0:00:05
#    ------------------- -------------------- 18.9/38.2 MB 4.2 MB/s eta 0:00:05
#    -------------------- ------------------- 19.7/38.2 MB 4.2 MB/s eta 0:00:05
#    --------------------- ------------------ 20.4/38.2 MB 4.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 21.2/38.2 MB 4.2 MB/s eta 0:00:05
#    ----------------------- ---------------- 22.0/38.2 MB 4.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 22.5/38.2 MB 4.1 MB/s eta 0:00:04
#    ------------------------ --------------- 23.3/38.2 MB 4.1 MB/s eta 0:00:04
#    ------------------------- -------------- 23.9/38.2 MB 4.1 MB/s eta 0:00:04
#    ------------------------- -------------- 24.6/38.2 MB 4.1 MB/s eta 0:00:04
#    -------------------------- ------------- 25.4/38.2 MB 4.0 MB/s eta 0:00:04
#    --------------------------- ------------ 26.2/38.2 MB 4.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 27.0/38.2 MB 4.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 27.8/38.2 MB 4.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.6/38.2 MB 4.0 MB/s eta 0:00:03
#    ------------------------------ --------- 29.4/38.2 MB 4.0 MB/s eta 0:00:03
#    ------------------------------- -------- 29.9/38.2 MB 4.0 MB/s eta 0:00:03
#    -------------------------------- ------- 30.7/38.2 MB 3.9 MB/s eta 0:00:02
#    -------------------------------- ------- 31.2/38.2 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 31.7/38.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 32.5/38.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.0/38.2 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.8/38.2 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.3/38.2 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------ --- 35.1/38.2 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 35.9/38.2 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 36.7/38.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  37.5/38.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 38.2/38.2 MB 3.7 MB/s  0:00:10
# Downloading pyee-13.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, playwright
#
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    ---------------------------------------- 2/2 [playwright]
#
# Successfully installed playwright-1.62.0 pyee-13.0.1

# %%
from langgraph.graph import StateGraph
from typing import Dict, Any
from IPython.display import Image, display

# Define nodes
def squeeze_lemons(state: Dict[str, Any]) -> Dict[str, Any]:
    state["juice"] = f"Juice from {state.get('lemons', 0)} lemons"
    return state

def add_sugar_and_water(state: Dict[str, Any]) -> Dict[str, Any]:
    state["mix"] = f"{state['juice']} + {state.get('sugar', 0)} spoons sugar + {state.get('water', '')} water"
    return state

def stir_and_serve(state: Dict[str, Any]) -> Dict[str, Any]:
    state["final"] = f"{state['mix']} → Stirred and ready to serve!"
    return state

from typing import TypedDict

class LemonState(TypedDict):
    lemons: int
    sugar: int
    water: str
    juice: str
    mix: str
    final: str


# Build graph
builder = StateGraph(LemonState)
builder.add_node("squeeze_lemons", squeeze_lemons)
builder.add_node("add_sugar_and_water", add_sugar_and_water)
builder.add_node("stir_and_serve", stir_and_serve)

builder.set_entry_point("squeeze_lemons")
builder.add_edge("squeeze_lemons", "add_sugar_and_water")
builder.add_edge("add_sugar_and_water", "stir_and_serve")
builder.set_finish_point("stir_and_serve")

graph = builder.compile()

# ✅ Visualize as Mermaid PNG
try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception as e:
    print("Visualization failed. Ensure Mermaid & pygraphviz dependencies are installed.")
    print(f"Error: {e}")

# %%
# Initial input state
initial_state: LemonState = {
    "lemons": 4,
    "sugar": 2,
    "water": "1 glass",
    "juice": "",
    "mix": "",
    "final": ""
}

# Run the LangGraph
result = graph.invoke(initial_state)

# Print final result
print("🧃 Final Output:", result["final"])
# Out:
# 🧃 Final Output: Juice from 4 lemons + 2 spoons sugar + 1 glass water → Stirred and ready to serve!
